# %%
# Import Benford.py
import benford as bf

# %%
# Creating stock name with it's values
apple = bf.stocks("Apple", "AAPL", API_KEY)

# %%
# Showcasing Daily Volume
apple.daily_volume()

# %%
apple.daily_delta()
# Out:
# /Users/seanfrey/Desktop/GitHub/finance/benfords-law/benford.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["diff"][i] = string.replace(string[:2], "") + "00"
# /Users/seanfrey/Desktop/GitHub/finance/benfords-law/benford.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["diff"][i] = string.replace(string[0], "") + "00"
# /Users/seanfrey/Desktop/GitHub/finance/benfords-law/benford.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
